# %%
# download code FaceLock from GitHub
# !git clone https://github.com/taco-group/FaceLock.git
# %cd FaceLock

# downloading libraries
# !pip install diffusers transformers accelerate insightface onnxruntime opencv-python
# Out:
# Cloning into 'FaceLock'...
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 37 (delta 13), reused 30 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (37/37), 688.25 KiB | 17.65 MiB/s, done.
# Resolving deltas: 100% (13/13), done.
# /content/FaceLock
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 762.2/762.2 kB 19.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 98.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 100.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
import os

print("upload your picture")
uploaded = files.upload()

for filename in uploaded.keys():
    os.rename(filename, "my_face.jpg")
    print("success, now it's name is my_face.jpg!")
# Out:
# upload your picture
#      <input type="file" id="files-7330041f-c964-499f-af3c-98e87353f46d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7330041f-c964-499f-af3c-98e87353f46d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# !python defend.py --input_path="my_face.jpg" --defend_method="facelock" --attack_budget=0.03
# Out:
# Traceback (most recent call last):
#   File "/content/FaceLock/defend.py", line 6, in <module>
#     import lpips
# ModuleNotFoundError: No module named 'lpips'

# %%
# !python edit.py --input_path="my_face.jpg" --prompt="a professional corporate headshot, studio lighting"
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model_index.json: 100% 616/616 [00:00<00:00, 2.26MB/s]
# ...
# Fetching 13 files: 100% 13/13 [00:38<00:00,  2.94s/it]
# Download complete: 100% 4.27G/4.27G [00:38<00:00, 94.3MB/s]
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]
# Loading pipeline components...:  17% 1/6 [00:06<00:31,  6.33s/it]
#
# Loading weights:   0% 0/196 [00:00<?, ?it/s]
#
# Loading weights:   1% 1/196 [00:00<00:00, 7281.78it/s, Materializing param=text_model.embeddings.position_embedding.weight]
#
# ...
